# %%
using Base.Test

# %%
#Image -> Boolean

# %%
#Produce true if image is tall

# %%
tall(img) = nothing #stub
# Out:
# tall (generic function with 1 method)

# %%
using FileIO, TestImages, Images, ImageView

# %%
img = load("Journey.jpg")
# Out:
# 650×1200 Array{RGB{N0f8},2}:
#  RGB{N0f8}(1.0,1.0,1.0)        …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)        …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)        …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,1.0,1.0)
#  ⋮                             ⋱
#  RGB{N0f8}(0.996,0.996,0.996)     RGB{N0f8}(0.996,0.996,0.996)
#  RGB{N0f8}(0.996,0.996,0.996)     RGB{N0f8}(0.996,0.996,0.996)
# ...

# %%
h, w = size(img)
# Out:
# (650, 1200)

# %%
@test tall(img) == false
# Out:
# Test Failed
#   Expression: tall(img) == false
#    Evaluated: nothing == false
# There was an error during testing
#
# Stacktrace:
#  [1] record(::Base.Test.FallbackTestSet, ::Base.Test.Fail) at ./test.jl:533
#  [2] do_test(::Base.Test.Returned, ::Expr) at ./test.jl:352

# %%
#Template
#tall(img) (... img)

# %%
tall(img) = h>w?true:false
# Out:
# tall (generic function with 1 method)

# %%
@test tall(img) == false
# Out:
# Test Passed
